# %% [markdown]
# # Assignment 12
# ### Readign data using WEB Api

# %%
import urllib.request
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
# API Key can be reterived from NYTimes Api page
key = 'b1426624d058405e80777903c4d8d385'
web_url = 'https://api.nytimes.com/svc/books/v3/lists/best-sellers/history.json?'

request = web_url+'&api-key='+key
response = str(urllib.request.urlopen(request).read(), 'utf-8')

best_seller_book = json.loads(response)
best_seller_book
# Out:
# {'copyright': 'Copyright (c) 2017 The New York Times Company.  All Rights Reserved.',
#  'num_results': 30998,
#  'results': [{'age_group': '',
#    'author': 'Diana Gabaldon',
#    'contributor': 'by Diana Gabaldon',
#    'contributor_note': '',
#    'description': 'The author of the Outlander novels gives tips on writing sex scenes, drawing on examples from the books.',
#    'isbns': [{'isbn10': '0399178570', 'isbn13': '9780399178573'}],
#    'price': 0,
#    'publisher': 'Dell',
#    'ranks_history': [{'asterisk': 0,
#      'bestsellers_date': '2016-08-20',
#      'dagger': 0,
#      'display_name': 'Advice, How-To & Miscellaneous',
#      'list_name': 'Advice How-To and Miscellaneous',
#      'primary_isbn10': '0399178570',
#      'primary_isbn13': '9780399178573',
#      'published_date': '2016-09-04',
#      'rank': 8,
#      'ranks_last_week': None,
#      'weeks_on_list': 1}],
#    'reviews': [{'article_chapter_link': '',
#      'book_review_link': '',
# ...

# %% [markdown]
# NYTImes Best seller book data is successfully retrieved using API provided by NYTimes.

# %%
DF = pd.DataFrame(data=best_seller_book['results'])
DF.head()
# Out:
#   age_group                                author  \
# 0                                  Diana Gabaldon
# 1            Annette Gordon-Reed and Peter S Onuf
# 2                                 Gary Vaynerchuk
# 3                                  Sophia Amoruso
# 4                                Chris Guillebeau
#
#                                 contributor contributor_note  \
# 0                         by Diana Gabaldon
# 1  by Annette Gordon-Reed and Peter S. Onuf
# 2                        by Gary Vaynerchuk
# 3                         by Sophia Amoruso
# 4                       by Chris Guillebeau
#
#                                          description  \
# 0  The author of the Outlander novels gives tips ...
# 1  A character study that attempts to make sense ...
# 2  The entrepreneur expands on subjects addressed...
# 3  An online fashion retailer traces her path to ...
# 4  How to build a profitable start up for $100 or...
#
# ...
